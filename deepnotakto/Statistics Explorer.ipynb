# %%
# General
import sys
import numpy as np
import matplotlib.pyplot as plt
from importlib import reload
sys.path.insert(0, '..')
# Deep-Notakto
import statistics

# %%
_ = reload(statistics)

# %%
# Get stats file
stats = statistics.get_stats("agents/saves/Goal4x4ReluJan25")
# Sort by stat
stats = statistics.group_stats_by_type(stats)

# %%
# Plot a desired value
statistics.plot_value(stats, ["q_wins", "avg_val"], fig_size = (15, 7))
